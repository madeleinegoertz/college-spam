# %%
import numpy as np
import pandas as pd

df = pd.read_csv("raw-email.csv",
                usecols=['Subject', 'Body', 'From: (Name)', 'From: (Address)'],
                #index_col='Subject',
                dtype='str')
df = df.rename(columns={'From: (Name)': 'Sender', 'From: (Address)': 'Email'})

# make all lowercase
df.columns = df.columns.str.strip().str.lower()
df = df.apply(lambda x: x.astype(str).str.lower())
#df.index = df.index.str.lower()
df = df.astype('string')
df
# Out:
#                                                 subject  \
# 0     strivescan's "colleges that change lives" virt...
# 1                   wooster is coming to you virtually.
# 2      experience a bard college at simon's rock class!
# 3                        faculty relationships run deep
# 4     how honors work can transform your college exp...
# ...                                                 ...
# 2649  virtual event: religious & spiritual life at h...
# 2650                               explore cornell cals
# 2651  looking for a college that will change your life?
# 2652                 pre-health advantages at rochester
# 2653                                      explore colby
#
#                                                    body  \
# 0     join our special event!  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌...
# 1     connect with us soon.
#  <https://eur06.safeli...
# 2     dear madeleine,
#
# would you like to experienc...
# 3
#  <https://mx.technolutions.net/proxy/k5ih0w...
# 4      <http://elink.alaska.edu/o/3/tvrrnu5ez3dpvfe6...
# ...                                                 ...
# 2649  join us to learn more about the religious and ...
# 2650  get a glimpse of cornell cals from your comput...
# 2651  ctcl virtual days
#  <https://nam11.safelinks....
# 2652   <https://mx.technolutions.net/proxy/teeczf7ia...
# 2653   <https://nam04.safelinks.protection.outlook.c...
#
#                                                  sender  \
# 0                         st. john's college admissions
# 1                                the college of wooster
# 2                                agabay@simons-rock.edu
# 3                                     lafayette college
# 4                        university of alaska fairbanks
# ...                                                 ...
# 2649                           johns hopkins university
# 2650  college of agriculture and life sciences admis...
# 2651                                   st. olaf college
# 2652                 university of rochester admissions
# 2653                 colby college office of admissions
#
#                                email
# 0                 admissions@sjc.edu
# 1             admissions@wooster.edu
# 2             agabay@simons-rock.edu
# 3           admissions@lafayette.edu
# 4          uaf-admissions@alaska.edu
# ...                              ...
# 2649                 gotojhu@jhu.edu
# 2650     cals_admissions@cornell.edu
# 2651           admissions@stolaf.edu
# 2652  admit@admissions.rochester.edu
# 2653            admissions@colby.edu
#
# [2654 rows x 4 columns]

# %%
# Remove all that aren't from an actual college or university
df = df.loc[df['email'].str.contains('.edu')].copy()
df
# Out:
#                                                 subject  \
# 0     strivescan's "colleges that change lives" virt...
# 1                   wooster is coming to you virtually.
# 2      experience a bard college at simon's rock class!
# 3                        faculty relationships run deep
# 4     how honors work can transform your college exp...
# ...                                                 ...
# 2649  virtual event: religious & spiritual life at h...
# 2650                               explore cornell cals
# 2651  looking for a college that will change your life?
# 2652                 pre-health advantages at rochester
# 2653                                      explore colby
#
#                                                    body  \
# 0     join our special event!  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌...
# 1     connect with us soon.
#  <https://eur06.safeli...
# 2     dear madeleine,
#
# would you like to experienc...
# 3
#  <https://mx.technolutions.net/proxy/k5ih0w...
# 4      <http://elink.alaska.edu/o/3/tvrrnu5ez3dpvfe6...
# ...                                                 ...
# 2649  join us to learn more about the religious and ...
# 2650  get a glimpse of cornell cals from your comput...
# 2651  ctcl virtual days
#  <https://nam11.safelinks....
# 2652   <https://mx.technolutions.net/proxy/teeczf7ia...
# 2653   <https://nam04.safelinks.protection.outlook.c...
#
#                                                  sender  \
# 0                         st. john's college admissions
# 1                                the college of wooster
# 2                                agabay@simons-rock.edu
# 3                                     lafayette college
# 4                        university of alaska fairbanks
# ...                                                 ...
# 2649                           johns hopkins university
# 2650  college of agriculture and life sciences admis...
# 2651                                   st. olaf college
# 2652                 university of rochester admissions
# 2653                 colby college office of admissions
#
#                                email
# 0                 admissions@sjc.edu
# 1             admissions@wooster.edu
# 2             agabay@simons-rock.edu
# 3           admissions@lafayette.edu
# 4          uaf-admissions@alaska.edu
# ...                              ...
# 2649                 gotojhu@jhu.edu
# 2650     cals_admissions@cornell.edu
# 2651           admissions@stolaf.edu
# 2652  admit@admissions.rochester.edu
# 2653            admissions@colby.edu
#
# [2432 rows x 4 columns]

# %%
import re
s = 'My name is Conrad, and blahblah@admissions.harvard.edu is my email.'
domain = re.search(r"(?<=@)[\w.-_]+(?=.edu)", s)
print(domain.group())

print(df.dtypes)
# Out:
# admissions.harvard
# subject    string
# body       string
# sender     string
# email      string
# dtype: object

# %%
# Get school from email domain
#df['school'] = df['email'].str.extract('(?<=@)([\w.-_]+)(?=.edu)').astype('string')
#print(df['school'].dtype)


# Alternate method for parsing school from email address.
# #1: Reverse email address
# #2: Regex: start after first '.', match all characters up until next '.' or '@'
# #3: Reverse match. 

#df['school'] = re.match(r"(?<=\.)[\w_-]+(?=(\.|@))", df['email'].str[::-1]).group()[::-1]
df['email_rev'] = df['email'].str[::-1]
df['school_rev'] = df['email_rev'].str.extract(pat=r'(?<=\.)([\w_-]+)(?=(\.|@))').astype('string')
df['school'] = df['school_rev'].str[::-1]
df = df.drop(['email_rev', 'school_rev'], axis=1)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'school_rev'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3573         try:
# -> 3574             loc = self._info_axis.get_loc(key)
#    3575         except KeyError:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#
# KeyError: 'school_rev'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-92b0056744a2> in <module>
#      11 #df['school'] = re.match(r"(?<=\.)[\w_-]+(?=(\.|@))", df['email'].str[::-1]).group()[::-1]
#      12 df['email_rev'] = df['email'].str[::-1]
# ---> 13 df['school_rev'] = df['email_rev'].str.extract(pat=r'(?<=\.)([\w_-]+)(?=(\.|@))').astype('string')
#      14 df['school'] = df['school_rev'].str[::-1]
#      15 df = df.drop(['email_rev', 'school_rev'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3115         self._ensure_valid_index(value)
#    3116         value = self._sanitize_column(key, value)
# -> 3117         NDFrame._set_item(self, key, value)
#    3118
#    3119         # check if we are modifying a copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3575         except KeyError:
#    3576             # This item wasn't present, just insert at end
# -> 3577             self._mgr.insert(len(self._info_axis), key, value)
#    3578             return
#    3579
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1187             value = _safe_reshape(value, (1,) + value.shape)
#    1188
# -> 1189         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1190
#    1191         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2720         values = DatetimeArray._simple_new(values, dtype=dtype)
#    2721
# -> 2722     return klass(values, ndim=ndim, placement=placement)
#    2723
#    2724
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2376             values = np.array(values, dtype=object)
#    2377
# -> 2378         super().__init__(values, ndim=ndim, placement=placement)
#    2379
#    2380     @property
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     128
#     129         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 130             raise ValueError(
#     131                 f"Wrong number of items passed {len(self.values)}, "
#     132                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 2, placement implies 1

# %%
schools = np.sort(df.school.unique())
print(schools)

# %%
# Remove the weird ones that aren't actually schools
df = df.loc[~df['school'].str.contains('exploringeducationalexcellence')].copy()
schools = np.sort(df.school.unique())
print(schools)

# %%
print("Num Schools = " + str(len(schools)))

# %%
schools_df = pd.DataFrame(index=schools)
schools_df.index.name = 'school'
schools_df['num_emails'] = None
schools_df

for school in schools:
    schools_df['num_emails'] = df[df.school == 'school'].shape[0]
schools_df.head(167)

# %%
# Alternate method for parsing school from email address.
# hello@admit.uw.edu
txt = 'hello@admit.uw.edu'
# reverse email
# ude.wu.timda@ollhe
txt = txt[::-1]
print(txt)
# regex: parse from 1st '.' to next '.' or '@'
# wu
import re
txt = re.search(r"(?<=\.)[\w_-]+(?=(\.|@))", txt)
print(txt.group())
# reverse string
# uw
txt = txt.group()[::-1]
print(txt)

# %%
# Alternate method for parsing school from email address.
# #1: Reverse email address
# #2: Regex: start after first '.', match all characters up until next '.' or '@'
# #3: Reverse match. 
txt = 'hello@admit.uw.edu'
txt = re.search(r"(?<=\.)[\w_-]+(?=(\.|@))", txt[::-1]).group()[::-1]

print(txt)
